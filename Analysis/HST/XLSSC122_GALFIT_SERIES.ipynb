# %%
import sys
sys.path.insert(0,'/data/emiln/XLSSU122/analysis/galfit/GalfitPyWrap/')
from GalfitPyWrap import galfitwrap as gf
import os

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import glob
from scipy import ndimage
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.io import fits
from astropy.io import ascii
from astropy import wcs
from astropy.table import Table, hstack, join
from __future__ import division
import fnmatch
import multiprocessing as mp
# %matplotlib inline

# Make plots readable
# Update plot params
# Make plots readable
params = {'legend.fontsize': 18,
	  'figure.figsize': (6,5),
	 'axes.labelsize': 22,
	 'axes.titlesize':22,
	 'xtick.labelsize':18,
	 'ytick.labelsize':18}
plt.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
plt.rc('text', usetex=True)
plt.rcParams.update(params)
# plt.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
# plt.rc('text', usetex=True)
# plt.rc('text.latex', preamble=r'\usepackage{cmbright}')
# plt.rcParams.update(params)
# Out:
# /data/emiln/miniconda2/lib/python2.7/site-packages/pyfits/__init__.py:22: PyFITSDeprecationWarning: PyFITS is deprecated, please use astropy.io.fits
#   PyFITSDeprecationWarning)  # noqa

# %%
# Load in XLSSC122 data

# f140_file = '/data/emiln/XLSSU122/xlssuj0217-0345-f140w_drz_sci.fits'
# f140_file_counts = '/data/emiln/XLSSU122/xlssuj0217-0345-f140w_drz_sci_COUNTS.fits'
# hdu = fits.open(f140_file)
# hdr = hdu[0].header
# data = hdu[0].data
# exptime = hdr['exptime']
# data = data * exptime # convert from CPS to counts
# hdu[0].data = data
# hdu.writeto(f140_file_counts, clobber=True)

# %%
# cat_file = '/data/emiln/XLSSU122/xlssc122_F105_F140_redshifts_short_v4_snr_em_member2_by_hand.cat'
# f140_file = '/data/emiln/XLSSU122/xlssuj0217-0345-f140w_drz_sci.fits'
# hdulist = fits.open(f140_file)
# w = wcs.WCS(hdulist[0].header)
# df = pd.read_csv(cat_file,delim_whitespace=True)
# df['X'] = w.wcs_world2pix(df['ra'],df['dec'], 1)[0]
# df['Y'] = w.wcs_world2pix(df['ra'],df['dec'], 1)[1]
# df_members = df[df['member1']>0.5]
# print len(df)
# print len(df_members)
# print df_members.columns.values
# df_members = df_members[df_members['f140_kron']<24]
# print len(df_members)
# # df_members['X'] = w.wcs_world2pix(df_members['ra'],df_members['dec'], 1)[0]
# # df_members['Y'] = w.wcs_world2pix(df_members['ra'],df_members['dec'], 1)[1]
# df_members

# %%
df1 = pd.read_csv('/data/emiln/XLSSU122/xlssuj0217-0345-f140w_drz_sci.cat',skiprows=9,delim_whitespace=True,header=0,names=['ID2','ra','dec','mag_auto','magerr_auto','mag_aper']+['g']*5+['magerr_aper']+['g']*5+['fwhm_world','flux_radius','flags'])
nround = 4
df1['ra2']=df1['ra'].round(nround)
df1['dec2']=df1['dec'].round(nround)
df1
# Out:
# /data/emiln/miniconda2/lib/python2.7/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# 1433     0.1683    0.000128        4.290      0  34.4391 -3.7387
# 1434     1.2077    0.000135        2.997      0  34.4396 -3.7397
# 1435     0.2063    0.000085        3.003      0  34.4320 -3.7381
# 1436     0.4014    0.000079        2.494      0  34.4340 -3.7377
# 1437     1.0340    0.000075        2.300      0  34.4496 -3.7396
# 1438     0.0651    0.000117        4.967      0  34.4279 -3.7392
# 1439     0.8453    0.000145        3.039      0  34.4348 -3.7363
# 1440     0.3551    0.000091        3.298      0  34.4230 -3.7390
# 1441     1.0496    0.000090        2.924      0  34.4304 -3.7381
# 1442     1.5590    0.000100        3.458      0  34.4377 -3.7375
# 1443  6808.9883    0.000062        3.170      0  34.4327 -3.7356
# 1444     0.5353    0.000060        2.285      0  34.4341 -3.7355
# 1445     0.6779    0.000185        5.475      0  34.4313 -3.7389
# 1446     0.3250    0.000211        3.760      0  34.4320 -3.7384
# 1447     0.0897    0.000102       14.080      2  34.4306 -3.7401
# 1448     3.7442    0.000113        2.563      0  34.4310 -3.7385
#
# [1449 rows x 22 columns]

# %%
df = pd.read_csv('/data/emiln/XLSSU122/xlssc122_F105_F140_redshifts_short_v4_snr_em_member2_by_hand.cat',delim_whitespace=True)
df['ra1']=df['ra'].round(nround)
df['dec1']=df['dec'].round(nround)
# df = df.merge(df1,left_on='phot-id',right_on='ID',how='inner',suffixes=["","_pc"])
df = df.merge(df1,left_on=['ra1','dec1'],right_on=['ra2','dec2'],how='inner',suffixes=["","_pc"])

df['gold_cluster'] = 0
df['gold_foreground'] = 0
df['silver_cluster'] = 0
df.columns.values
df['(f140)kron'] = df['f140_kron']
for i,r in df.iterrows():
    if (r['member1']>0.5) and (r['(f140)kron']<24 or (r['(f140)kron']<24.5 and r['em-code']==1)):
#         print 'cluster mem'
        df.at[i,'gold_cluster'] = 1
    if (r['member1']<0.5 and r['member1']>0.1) and (r['(f140)kron']<24 or (r['(f140)kron']<24.5 and r['em-code']==1)):
#         print 'cluster mem'
        df.at[i,'silver_cluster'] = 1
    if (r['member2']>0.5) and (r['(f140)kron']<24 or (r['(f140)kron']<24.5 and r['em-code']==1)):
        df.at[i,'gold_foreground'] = 1  
print df['silver_cluster'].sum()
print df['gold_cluster'].sum()
print df['gold_foreground'].sum()
# Compute color for each cluster member
df['color'] = df['f105_0p8'] - df['f140_0p8']
df['F140W'] = df['f140_kron']
df['ID'] = df['phot-id']
# Compute r/r500 for each cluster member
# Cluster Center
cluster_ra = 34.434125
cluster_dec = -3.7587388
r500 = 35 # arcsec
df['r_center'] = np.sqrt((df['ra']-cluster_ra)**2 + (df['dec']-cluster_dec)**2)*3600./r500
df['r_center'].hist()

f140_file = '/data/emiln/XLSSU122/xlssuj0217-0345-f140w_drz_sci.fits'
hdulist = fits.open(f140_file)
w = wcs.WCS(hdulist[0].header)
# df = pd.read_csv(cat_file,delim_whitespace=True)
df['X'] = w.wcs_world2pix(df['ra'],df['dec'], 1)[0]
df['Y'] = w.wcs_world2pix(df['ra'],df['dec'], 1)[1]


members1 = df[df['gold_cluster']==1]
members2 = df[df['gold_foreground']==1]
members1s = df[df['silver_cluster']==1]

members = df[(df['gold_cluster']==1) | (df['silver_cluster']==1)]
plt.show()
members['color'].hist(bins=np.linspace(0,2,10))
# members['F140W'] = members['f140_kron']
# members['ID'] = members['phot-id']
XLSSC122_df = df
# Out:
# 4
# 33
# 13
# /data/emiln/miniconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#        'gold_foreground', 'silver_cluster', '(f140)kron', 'color',
#        'F140W', 'ID', 'r_center', 'X', 'Y'], dtype=object)

# %%
# Line graph of average color in radial bins

r_bins = np.linspace(0,2,5)
r_mid = (r_bins[1:] + r_bins[:-1])/2
# r_bins = [0,0.5,1,1.5,2]
# r_bins = np.logspace(0.1,2,4)
mean_c = []

for i in range(0,len(r_bins)-1):
    rlo = r_bins[i]
    rhi = r_bins[i+1]
    tdf = members[(members['r_center']<rhi) & (members['r_center']>rlo)]
    print "N = ", len(tdf)
    c = tdf['color'].mean()
    print c
    mean_c.append(c)
    
plt.plot(r_mid, mean_c)
# Out:
# N =  9
# 1.2634222222222213
# N =  8
# 1.191912499999999
# N =  10
# 0.8119900000000001
# N =  8
# 0.8320874999999992

# %%
from scipy.stats import poisson, binom
import scipy.stats.distributions as dist
def CalcGehrels_Binomial(n,ngal):
    '''
    http://articles.adsabs.harvard.edu/pdf/1986ApJ...303..336G
    https://arxiv.org/pdf/1012.0566.pdf

    Lo Error for k=0 is >0 for some reason, needs fix
    Upper error for some fagn is < fagn
    '''
    try:
            ngal = ngal.astype(int)
    except:
            ngal = int(ngal)
            n = int(n)
    k=n
    n=ngal
    c = 0.683 # 1 sigma 

    print("n:",n)
    print("k:",k)
    print("p:",k/n)

    err_lo = dist.beta.ppf((1-c)/2.,k+1,n-k+1)
    err_hi = dist.beta.ppf(1-(1-c)/2.,k+1,n-k+1)
    print("err_lo:", err_lo)
    print("err_hi:",err_hi)

    return err_lo, err_hi

# %%
# Quiescent fraction as f(r)
r_bins = np.linspace(0,2,4)
r_mid = (r_bins[1:] + r_bins[:-1])/2
# r_bins = [0,0.5,1,1.5,2]
# r_bins = np.logspace(0.1,2,4)
mean_c = []
nq = []
nt = []

cthresh = 1

for i in range(0,len(r_bins)-1):
    rlo = r_bins[i]
    rhi = r_bins[i+1]
    tdf = members[(members['r_center']<rhi) & (members['r_center']>rlo)]
    print "N = ", len(tdf)
    c = tdf['color'].mean()
    print c
    mean_c.append(c)
    nq.append(len(tdf[tdf['color']>cthresh]))
    nt.append(len(tdf))

nq = np.array(nq)
nt = np.array(nt)
print nq
print nt

qf = nq/nt

err_lo, err_hi = CalcGehrels_Binomial(nq,nt)
plt.figure(figsize=(4.5,4))
plt.errorbar(r_mid, qf,xerr=(r_bins[1]-r_bins[0])/2,yerr=[qf-err_lo,err_hi-qf],fmt='o',color='red')
plt.ylabel('Quiescent Fraction')
plt.xlabel(r'$r/r_{500}$')
plt.ylim(0,1)
plt.xlim(0,2)

plt.tight_layout()
plt.savefig('XLSSC122_QF_2r500.pdf')
# Out:
# N =  12
# 1.155641666666666
# N =  11
# 1.058663636363636
# N =  12
# 0.8474749999999993
# [9 7 5]
# [12 11 12]
# ('n:', array([12, 11, 12]))
# ('k:', array([9, 7, 5]))
# ('p:', array([0.75      , 0.63636364, 0.41666667]))
# ('err_lo:', array([0.59441922, 0.48058123, 0.29661406]))
# ('err_hi:', array([0.83316874, 0.74958585, 0.56084805]))

# %% [markdown]
# ### GALFIT SETUP

# %% [markdown]
# ### LOAD FUNCTIONS AND DATA

# %%
ncpu = mp.cpu_count()
print ncpu
# Out:
# 8

# %%
def run_galfit_cosmos_parallel(row1,OG_df=XLSSC122_df,zp=25,width=90,HLwidth=False,PSFf=1,use_psf=True,\
                               timeout=300,verb=False,psf_file='none',\
                               sigma_file='none',cutout_file='none',\
                               save_name='testsave',\
                              PA_INIT=45, AR_INIT=0.5, MAG_INIT=21,DYNMAG=False, convbox='50 50',
                              constr='none',cutout_width = 200, badmask='none', MAGFIT=False, mag_thresh=5,
                               sky='Default',skyINIT=0.000001, N=0):
#     cutout_width = 200 # ALWAYS KEEP THE SAME, PHYSICAL SIZE OF CUTOUTS FROM DATA_PREP
#     N = 0 # Extra width to search for neighbours in?
#     mag_thresh = 4 # Neighbours only fit if less than mag_thresh fainter than primary
    
    df = OG_df
    r = row1
    ra = r.ra
    dec = r.dec
    ID = int(r['phot-id'])
#     if badmask != 'none':
#         print "Using bad pixel mask..."
#         badmask = tdir+badmask
    if DYNMAG:
        MAG_INIT=np.round(r.F140W,decimals=2)
#         MAG_INIT=np.round(r.F140W_fixed,decimals=2)
        og_mag=MAG_INIT
        print "Initializing",str(ID),"with F140W magnitude:", MAG_INIT
#     pixcrd = full_wcs.wcs_world2pix(ra,dec, 1)
#     print pixcrd
#     X = int(pixcrd[0])
#     Y = int(pixcrd[1])
    X = r.X
    Y = r.Y
    
#     ids_all.append(ID)
    CX = cutout_width
    CY = cutout_width
    
    if MAGFIT:
        magf = 1
    else:
        magf = 0

    print "ID", ID
    print "RA:",ra
    print "DEC:",dec
    print "Initial X:", X
    print "Initial Y:", Y
    print "Cutout X:", CX 
    print "Cutout Y:", CY
    print "Cutout width:", cutout_width

    tdir = '/data/emiln/XLSSU122/analysis/XLSSC122/galfit_results/'+str(ID)
    
    model=[{
    0: 'sersic',              #  object type
    1: str(CX)+' '+str(CY)+' 1 1', #  position x, y
    3: str(MAG_INIT)+' '+str(magf),            #  Integrated magnitude   
    4: '10 1',            #  R_e (half-light radius)   [pix]
    5: '4 1',            #  Sersic index n (de Vaucouleurs n=4) 
    9: str(AR_INIT)+' 1',            #  axis ratio (b/a)  
    10: str(PA_INIT)+' 1',         #  position angle (PA) [deg: Up=0, Left=90]
    'Z': 0                   #  output option (0 = resid., 1 = Don't subtract) 
    }]

    if HLwidth == False:
        bounds = [CX-width,CX+width,CY-width,CY+width]
        bounds2 = [X-width,X+width,Y-width,Y+width]
        print "Cutoutwidth (pixels):", width*2
        print "Cutoutwidth (arcsec):", width*2*0.06
    else: 
        width = int(np.ceil(HLwidth*r.flux_radius))
        print 'r.flux_radius:', r.flux_radius
        bounds = [CX-width,CX+width,CY-width,CY+width]
        bounds2 = [X-width,X+width,Y-width,Y+width]
        print "Cutoutwidth (pixels) for ID",str(ID),":", width*2
        print "Cutoutwidth (arcsec) for ID",str(ID),":", width*2*0.06
        
    print "Bounds:", bounds

    # Find neighbours in full DF
    # Neighbour check needs to be done on original fits image / catalog
    ndf = df[(df['X']>(bounds2[0]-N)) & (df['X']<(bounds2[1]+N)) & (df['Y']>(bounds2[2]-N)) & (df['Y']<(bounds2[3]+N))
             & (df['ID']!=ID)]

    print len(ndf),"NEIGHBOURS FOUND"

    print "Adding additional model components for neighbours..."
    for row in ndf.iterrows():
        r = row[1]
        NX = r.X - X + cutout_width
        NY = r.Y - Y + cutout_width
        if DYNMAG:
            MAG_INIT=np.round(r.F140W,decimals=2)
#             MAG_INIT=np.round(r.F140W_fixed,decimals=2)
            if np.isnan(MAG_INIT):
                MAG_INIT=og_mag # Initialize with MAG of primary target
                print "***NEIGHBOUR MAG NOT CATALOGED***"
            print "NEIGHBOUR initialized with F140W Kron magnitude:", MAG_INIT
            if MAG_INIT > og_mag+mag_thresh:
                print "Neighbour mag too faint, not being fit"
                continue # If mag is too faint, do not fit this object (Should eventually mask these)
                
        seqnr = int(r['ID'])
        model.append({
                0: 'sersic',              #  object type
                1: str(NX)+' '+str(NY)+' 1 1', #  position x, y
                3: str(MAG_INIT)+' '+str(magf),            #  Integrated magnitude   
                4: '10 1',            #  R_e (half-light radius)   [pix]
                5: '4 1',            #  Sersic index n (de Vaucouleurs n=4) 
                9: str(AR_INIT)+' 1',            #  axis ratio (b/a)  
                10: str(PA_INIT)+' 1',         #  position angle (PA) [deg: Up=0, Left=90]
                'Z': 0                   #  output option (0 = resid., 1 = Don't subtract) 
                })


    if use_psf:
        print "Using PSF"
#         O=gf.CreateFile(tdir+cutout_file, bounds, model,fout=tdir+'/input.feedme',\
#                         Pimg=psf_file, Simg=tdir+sigma_file, ZP=zp, scale='0.06 0.06',PSFf=PSFf, convbox=convbox,
#                        constr=constr, badmask=badmask, sky=sky,skyINIT=skyINIT)
        
        O=gf.CreateFile(tdir+cutout_file, bounds, model,fout=tdir+'/input.feedme',\
                Pimg=psf_file, ZP=zp, scale='0.06 0.06',PSFf=PSFf, convbox=convbox,
               constr=constr, badmask=badmask, sky=sky,skyINIT=skyINIT)
        # convbox should be larger than PSF. f125_400 psf is (166,166)
    else:
        O=gf.CreateFile(tdir+cutout_file, bounds, model,fout=tdir+'/input.feedme',\
                        Simg=tdir+sigma_file, ZP=zp, scale='0.06 0.06', PSFf=PSFf, convbox=convbox, constr=constr,
                       badmask=badmask,sky=sky,skyINIT=skyINIT)

    p,oimg,mods,EV,chi2nu=gf.rungalfit(tdir+'/input.feedme',verb=verb, timeout=timeout)
    if EV==124: print "***PROCESS TIMEOUT***"
    bad_result = False
    print '****',ID,'****'
    try: 
        os.rename('out.fits',tdir+'/out_'+save_name+'.fits')
        os.rename('fit.log',tdir+'/fit_'+save_name+'.log')
        os.rename('galfit.01',tdir+'/galfit_'+save_name+'.01')
    except:
        print "***",ID,"Fit failed at GALFIT level***"
        

    try:
#         print "start try"
        print mods
        re_all = mods[0]['1_RE'].split(' ')
        ar_all = mods[0]['1_AR'].split(' ')
        n_all = mods[0]['1_N'].split(' ')
        m_all = mods[0]['1_MAG'].split(' ')
        s_all = mods[-1][str(len(mods))+'_SKY'].split(' ')
#         print "split('') complete"
        re_val = re_all[0].split('*')
        re_err_val = re_all[2].split('*')
        ar_val = ar_all[0].split('*')
        ar_err_val = ar_all[2].split('*')
        m_val = m_all[0].split('*')
        m_err_val = m_all[2].split('*')
        n_val = n_all[0].split('*')
        n_err_val = n_all[2].split('*')
        s_val = s_all[0].split('*')
        s_err_val = s_all[2].split('*')
#         print "split('*') complete"
        
        print re_val
        print re_err_val
        print m_val
        print m_err_val
        print ar_val
        print ar_err_val
        print s_val
        print s_err_val

        if len(re_val)>1:
#             EV+=2**2
            print 'ID',str(ID),'len(re_val)>1', len(re_val)>1

        if len(ar_val)>1:
#             EV+=2**3
            print 'ID',str(ID),'len(ar_val)>1', len(ar_val)>1

        if len(n_val)>1:
#             EV+=2**4
            print 'ID',str(ID),'len(n_val)>1', len(n_val)>1

        if len(m_val)>1:
#             EV+=2**5
            print 'ID',str(ID),'len(m_val)>1', len(m_val)>1
            
        if len(s_val)>1:
#             EV+=2**5
            print 'ID',str(ID),'len(s_val)>1', len(s_val)>1
            
#         print "EV updated for *"
        
        
#         print 'int(np.ceil(len(re_val)/2.)-1)', int(np.ceil(len(re_val)/2.)-1)
        re = float(re_val[int(np.ceil(len(re_val)/2.)-1)])
#         print 're', re
        
#         print 'int(np.ceil(len(re_err_val)/2.)-1)', int(np.ceil(len(re_err_val)/2.)-1)
        re_err = float(re_err_val[int(np.ceil(len(re_err_val)/2.)-1)])
#         print 're_err', re_err
        
#         print int(np.ceil(len(ar_val)/2.)-1)
        ar = float(ar_val[int(np.ceil(len(ar_val)/2.)-1)])
#         print ar
        ar_err = float(ar_err_val[int(np.ceil(len(ar_err_val)/2.)-1)])
#         print ar_err
        n = float(n_val[int(np.ceil(len(n_val)/2.)-1)])
#         print n
        n_err = float(n_err_val[int(np.ceil(len(n_err_val)/2.)-1)])
#         print n_err
        m = float(m_val[int(np.ceil(len(m_val)/2.)-1)])
#         print m
        m_err = float(m_err_val[int(np.ceil(len(m_err_val)/2.)-1)])
    
        s = float(s_val[int(np.ceil(len(s_val)/2.)-1)])
        s_err = float(s_err_val[int(np.ceil(len(s_err_val)/2.)-1)])

                       
    except:
        print "EXCEPTION"
        re_all = [-99,-99,-99]
        ar_all = re_all
        n_all = re_all
        m_all = re_all
        s_all = re_all
        re = float(re_all[0])
        re_err = float(re_all[2])
        ar = float(ar_all[0])
        ar_err = float(ar_all[2])
        n = float(n_all[0])
        n_err = float(n_all[2])
        m = float(m_all[0])
        m_err = float(m_all[2])
        s = float(s_all[0])
        s_err = float(s_all[2])
        EV+=999

    return ID,ra,dec, re, re_err, ar, ar_err, n, n_err, m, m_err, s, s_err, chi2nu, EV
#     return ID,ra,dec, re, ar, n, m, s, chi2nu, EV

# %%
def plot_by_ID(ID,save_name=None,cos_df=None,catalog=False):
    if not save_name:
        print 'provide a save_name...'
        return
    tdir = '/data/emiln/XLSSU122/analysis/XLSSC122/galfit_results/'+str(ID)
    
#     ttdf = pd.read_csv('COSMOS_test_galfit_results_'+save_name+'.csv')
    ttdf = pd.read_csv('results/'+save_name+'.csv')
    print 'ID:',ID
    print 'ttdf[ID]',ttdf['ID']
#     print ttdf[ttdf['ID'] == ID]
#     print ID
    try: 
        oimg = fits.open(tdir+'/out_'+save_name+'.fits')
        showme3(oimg)
    except:
        print "No model fit found. Plotting raw image from /cutout.fits"
        try:
            oimg = fits.open(tdir+'/cutout.fits')
            vm = np.percentile(oimg[0].data,99)
            plt.figure()
            plt.subplot(131)
            plt.imshow(oimg[0].data,interpolation='none',cmap='viridis',vmin=1e-4,vmax=vm)
        except:
            print "No cutout.fits file found..."
            oimg = fits.open(tdir+'/data_cps.fits')
            vm = np.percentile(oimg[0].data,99)
            plt.figure(figsize=(5,5))
            plt.subplot()
            plt.imshow(oimg[0].data,interpolation='none',cmap='viridis',vmin=1e-4,vmax=vm)
    if catalog:    
        print '\n ***CATALOG PARAMS***'
        print cos_df[cos_df['NUMBER']==ID][['q','n','re']]
    plt.show()

# %%
def summarize_results(galfit_file):
    df2 = pd.read_csv(galfit_file)
    print len(df2[df2['n']==-99])
    df = df2[df2['n']!=-99]

#     plt.hist(cos_df['n'],bins=np.linspace(0,10,20),alpha=0.5,color='blue', label='Catalog')
    plt.hist(df['n'],bins=np.linspace(0,10,20), alpha=0.5,color='red')
    plt.xlabel('Sersic index, n')
    plt.legend()
    plt.show()
#     print np.max(cos_df['n'])

#     plt.hist(cos_df['re'],bins=np.linspace(0,6,30),alpha=0.5,color='blue', label='Catalog')
    plt.hist(df['re']*0.06,bins=np.linspace(0,6,30), alpha=0.5,color='red')
    plt.xlabel('Effective radius (\'\')')
    plt.legend()
    plt.show()

#     plt.hist(cos_df['q'],bins=np.linspace(0,1,20),alpha=0.5,color='blue', label='Catalog')
    plt.hist(df['ar'],bins=np.linspace(0,1,20), alpha=0.5,color='red')
    plt.xlabel('Axis ratio, q')
    plt.legend()
    plt.show()
    
#     mdf = df.merge(hst_df,on='ID',suffixes=('_M','_C'))
    mdf = df.merge(zhst_df,on='ID',suffixes=('_M','_C'))
    #     print mdf.columns.values    
    kpa = cosmo.kpc_proper_per_arcmin(mdf['z']).value/60

    mdf['re_kpc'] = mdf['re']*0.06 * kpa # re[pixels] * 0.06 arcsec/pixel * kpa/arcsec
    
    mdf['F125W'] = 25.0 - 2.5 * np.log10(mdf['f_F125W'])
    mdf['F160W'] = 25.0 - 2.5 * np.log10(mdf['f_F160W'])
    mdf['F814W'] = 25.0 - 2.5 * np.log10(mdf['f_F814W'])
    
    mdf['mag_M-mag_C-1.5'] = mdf['mag'] - (mdf['F140W']-1.465)
    
    plt.scatter(mdf['F140W'],mdf['mag'],alpha=0.3)
    plt.plot([15,26],[15,26],'k--')
    plt.ylabel('measured Mag')
    plt.xlabel('catalog F140W')
    plt.xlim([21,25])
    plt.ylim([21,25])
    plt.show()
    
    plt.scatter(mdf['F140W']-1.465,mdf['mag'],alpha=0.3)
    plt.plot([15,26],[15,26],'k--')
    plt.ylabel('measured Mag')
    plt.xlabel('catalog F140W - 1.465')
    plt.xlim([21,25])
    plt.ylim([21,25])
    plt.show()
    
    return mdf

# %%
# p,oimg,mods,EV=gf.rungalfit('test.input')
def showme3(oimg,fignum=None):
    vm = np.max(oimg[1].data)
#     print vm
    
    plt.figure(fignum)
    plt.subplot(131)
    plt.imshow(oimg[1].data,interpolation='none',cmap='viridis',vmin=1e-4,vmax=vm)
    plt.subplot(132)
    plt.imshow(oimg[2].data,interpolation='none',cmap='viridis',vmin=1e-4,vmax=vm)
    plt.subplot(133)
    plt.imshow(oimg[3].data,interpolation='none',cmap='viridis',vmin=1e-4,vmax=vm)
#     plt.subplot(131)
#     plt.imshow(np.arcsinh(oimg[1].data/50),interpolation='none',cmap='viridis')
#     plt.subplot(132)
#     plt.imshow(np.arcsinh(oimg[2].data/50),interpolation='none',cmap='viridis')
#     plt.subplot(133)
#     plt.imshow(np.arcsinh(oimg[3].data/50),interpolation='none',cmap='viridis')
# showme3(oimg)

# %%
# df = members
# f140_file = '/data/emiln/XLSSU122/xlssuj0217-0345-f140w_drz_sci.fits'
# hdulist = fits.open(f140_file)
# w = wcs.WCS(hdulist[0].header)
# df = pd.read_csv(cat_file,delim_whitespace=True)
# df['X'] = w.wcs_world2pix(df['ra'],df['dec'], 1)[0]
# df['Y'] = w.wcs_world2pix(df['ra'],df['dec'], 1)[1]

# %%
df[df['phot-id']==661]['flux_radius']
# Out:
# 52    64.93
# Name: flux_radius, dtype: float64

# %% [markdown]
# ### RUN GALFIT

# %%
##### save_name = 'rmssigmameanexp_w190_400PSF_PARALLEL_10min_CONSTR_40conv_TEST'

tdf = members[0:4]
df_name = 'XLSSC122_galfit_TEST'
test = True

print len(tdf)

print 'FINAL ID:', max(tdf['ID'])

# pool = mp.Pool(mp.cpu_count()) # cos_df[0:7], 4min 40s with 8 CPU
pool = mp.Pool(4) #  4min 40s, with 4 CPU

# psf_file = 'f125w_400_400_6arcsec_psf.fits' # 0.036 ''/pix
# psf_name = '400PSF'
# psf_file = 'resampled_CDKinterp_convolved_PSF.fits' # 0.06 '' /pix, CDK was interpolated and convolved at this pixscale
# psf_name = 'CDK_int_conv_PSF'

# psf_file = 'PSF/cosmos_3dhst.v4.0.F140W_psf.fits' # 
psf_file = '../3dhst/PSF/cosmos_3dhst.v4.0.F140W_psf.fits' # 
psf_name = '3DHST_F140W_PSF'

# psf_file = 'SUBSAMPLED_PSF00.fits' # 0.013 ''/pix (10x oversampled from WFC3 pix scale, 0.013''/pix)
PSFf = 1 # Fine sampling factor of PSF (integer). COSMOS image is 0.06''/pixel. If PSF is 0.03''/pixel -> PSFf = 2
convbox='50 50'
cutout_width = 400 # 200 for mag<23 objects, 400 for z2 objects
# convbox='200 200'
# timeout=2*300 # maximum fit run time, test 30min runtime, if running on 8 threads, 4 processes will idle --> set timeout to 2* normal
timeout=5*60
verb=False

w=50
HLwidth=10 # Cutout width = 2*HLwidth
# HLwidth=False

PA_INIT = 45
AR_INIT = 0.5
zp = 25
# zp = 26.465
# 26.465? https://iopscience.iop.org/article/10.1088/0067-0049/214/2/24/pdf page 13
# page 20 --> All cataloged fluxes are normalized to AB zero point = 25
MAG_INIT = 21
MAGFIT = True
mag_thresh=2
DYNMAG = True
sky='Default' # {'Default','None'} : Default = {0: 'sky', 1: str(skyINIT)+' 1', 2: '0 0', 3: '0 0', 'Z': 0, 'Comment': 'StandardSky'}
# sky = 'None'
skyINIT=0.00001 # sky subtracted data

# sigma_file = '/sigma_meanexp_cutout.fits'
# sigma_file = '/sigma_rms_meanexp_cps.fits'
sigma_file='none'
# sigma_file = '/sigma_meanexp_counts.fits'
# sigma_file = '/sigma_meanexp_counts_ADU_exp_adjusted.fits' #exposure header adjusted to 1900s --> https://archive.stsci.edu/pub/hlsp/candels/cosmos/cos-tot/v1.0/hlsp_candels_hst_cos-tot_readme_v1.0.pdf

# cutout_file = '/cutout.fits'
cutout_file = '/data_cps.fits'
# cutout_file = '/counts_cutout_meanexp_ADU.fits'
# cutout_file = '/counts_cutout_meanexp_ADU_exp_adjusted.fits' #exposure header adjusted to 1900s --> https://archive.stsci.edu/pub/hlsp/candels/cosmos/cos-tot/v1.0/hlsp_candels_hst_cos-tot_readme_v1.0.pdf

# constr_file = 'galfit_constr.txt' # Matches van der wel 2012 constraints
constr_file = 'none'


badmask='none'
# badmask='/20p_mask.fits'

save_name = df_name+'_'+cutout_file[1:-5]+'_'+sigma_file[1:-5]+'_w'+\
            [str(HLwidth)+'HLR' if HLwidth!=False else str(w)][0]+'_'+psf_name+'_'+\
            str(int(timeout/60))+'min_CONV'+convbox.split(' ')[0]+\
            ['_CONSTR' if constr_file !='none' else ''][0]+['_DYNMAG' if DYNMAG else ''][0]+\
            ['_TEST' if test else ''][0]

print 'SAVE_NAME:', save_name


# results = [pool.apply_async(run_galfit_cosmos_parallel, args=([r])) for idx, r in tdf.iterrows()]

results = [pool.apply_async(run_galfit_cosmos_parallel, args=([r]), kwds={'OG_df':XLSSC122_df,'width':w,\
            'sigma_file':sigma_file,'cutout_file':cutout_file,\
            'save_name':save_name,'psf_file':psf_file,\
            'use_psf':True,'timeout':timeout,'PSFf':PSFf,'verb':verb,'HLwidth':HLwidth,\
             'PA_INIT':PA_INIT, 'AR_INIT':AR_INIT, 'MAG_INIT':MAG_INIT, 'convbox':convbox,\
            'zp':zp,'constr':constr_file,'cutout_width':cutout_width,'DYNMAG':DYNMAG,\
             'badmask':badmask,'MAGFIT':MAGFIT, 'sky':sky,'skyINIT':skyINIT, 'mag_thresh':mag_thresh}) for idx, r in tdf.iterrows()]

output = [p.get() for p in results]
pool.close()
print output

# new_df = pd.DataFrame(output,columns=['ID','ra','dec','re','ar','n','mag','sky','chi2nu','ErrorValue']) 
new_df = pd.DataFrame(output,columns=['ID','ra','dec','re','re_err','ar','ar_err','n','n_err','mag','mag_err','sky','sky_err','chi2nu','ErrorValue']) 
# ErrorValue of 124 = process timeout, 1 = GALFIT exception
new_df.to_csv('results/'+save_name+'.csv',index=False)
new_df
# Out:
# 4
# FINAL ID: 1036
# Initializing 529 with F140W magnitude: 20.64
# ID 529
# RA: 34.434215
# DEC: -3.758796
# Initializing 455 with F140W magnitude: 21.95
# Initial X: 2197.563194431937
# ID 455
# Initializing 661 with F140W magnitude: 21.67
# RA: 34.422282
# DEC: -3.7635129999999997
# ID 661
# Initializing 1036 with F140W magnitude: 22.38
# Initial Y: 2196.523772150128
# RA: 34.434096000000004
# Initial X: 2911.998955527549
# DEC: -3.757658
# Cutout X: 400
# ID 1036
# Initial X: 2204.6878979303997
# Cutout Y: 400
# Initial Y: 1913.4983304619273
# RA: 34.43245
# Initial Y: 2264.803766147215
# Cutout width: 400
# Cutout X: 400
# Cutout X: 400
# DEC: -3.7499239999999996
# r.flux_radius: 27.129
# Cutout Y: 400
# Cutout Y: 400
# Initial X: 2303.2368803656964
# Cutout width: 400
# Cutoutwidth (pixels) for ID 529 : 544
# Initial Y: 2728.843588761754
# r.flux_radius: 64.93
# Cutoutwidth (arcsec) for ID 529 : 32.64
# Cutout X: 400
# Cutout width: 400
# Cutoutwidth (pixels) for ID 661 : 1300
# Bounds: [128, 672, 128, 672]
# r.flux_radius: 5.784
# Cutout Y: 400
# Cutoutwidth (arcsec) for ID 661 : 78.0
# Cutout width: 400
# Cutoutwidth (pixels) for ID 455 : 116
# Bounds: [-250, 1050, -250, 1050]
# Cutoutwidth (arcsec) for ID 455 : 6.96
# r.flux_radius: 4.6080000000000005
# Cutoutwidth (pixels) for ID 1036 : 94
# Cutoutwidth (arcsec) for ID 1036 : 5.64
# 99 NEIGHBOURS FOUND
# Bounds: [353, 447, 353, 447]
# Adding additional model components for neighbours...
# NEIGHBOUR initialized with F140W Kron magnitude: 21.45
# 448 NEIGHBOURS FOUND
# Bounds: [342, 458, 342, 458]
# NEIGHBOUR initialized with F140W Kron magnitude: 21.67
# Adding additional model components for neighbours...
# NEIGHBOUR initialized with F140W Kron magnitude: 22.52
# NEIGHBOUR initialized with F140W Kron magnitude: 22.99
# 2 NEIGHBOURS FOUND
# Adding additional model components for neighbours...
# NEIGHBOUR initialized with F140W Kron magnitude: 20.36
# Neighbour mag too faint, not being fit
# 9 NEIGHBOURS FOUND
# NEIGHBOUR initialized with F140W Kron magnitude: 20.3
# NEIGHBOUR initialized with F140W Kron magnitude: 26.32
# NEIGHBOUR initialized with F140W Kron magnitude: 22.4
# Adding additional model components for neighbours...
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 21.45
# NEIGHBOUR initialized with F140W Kron magnitude: 23.38
# NEIGHBOUR initialized with F140W Kron magnitude: 26.23
# NEIGHBOUR initialized with F140W Kron magnitude: 21.12
# NEIGHBOUR initialized with F140W Kron magnitude: 25.64
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 21.15
# Using PSF
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 20.64
# NEIGHBOUR initialized with F140W Kron magnitude: 25.09
# NEIGHBOUR initialized with F140W Kron magnitude: 20.86
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 21.17
# NEIGHBOUR initialized with F140W Kron magnitude: 26.28
# NEIGHBOUR initialized with F140W Kron magnitude: 21.92
# NEIGHBOUR initialized with F140W Kron magnitude: 21.59
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 21.74
# NEIGHBOUR initialized with F140W Kron magnitude: 26.69
# NEIGHBOUR initialized with F140W Kron magnitude: 21.91
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.15
# NEIGHBOUR initialized with F140W Kron magnitude: 23.25
# NEIGHBOUR initialized with F140W Kron magnitude: 26.01
# NEIGHBOUR initialized with F140W Kron magnitude: 22.15
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.38
# NEIGHBOUR initialized with F140W Kron magnitude: 23.58
# NEIGHBOUR initialized with F140W Kron magnitude: 27.32
# NEIGHBOUR initialized with F140W Kron magnitude: 22.5
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.69
# NEIGHBOUR initialized with F140W Kron magnitude: 27.21
# NEIGHBOUR initialized with F140W Kron magnitude: 23.6
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.88
# NEIGHBOUR initialized with F140W Kron magnitude: 23.47
# NEIGHBOUR initialized with F140W Kron magnitude: 27.51
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.73
# NEIGHBOUR initialized with F140W Kron magnitude: 23.58
# NEIGHBOUR initialized with F140W Kron magnitude: 22.1
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.25
# NEIGHBOUR initialized with F140W Kron magnitude: 27.27
# NEIGHBOUR initialized with F140W Kron magnitude: 22.1
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.44
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.52
# NEIGHBOUR initialized with F140W Kron magnitude: 27.83
# NEIGHBOUR initialized with F140W Kron magnitude: 22.85
# NEIGHBOUR initialized with F140W Kron magnitude: 23.9
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.34
# Using PSF
# NEIGHBOUR initialized with F140W Kron magnitude: 22.43
# NEIGHBOUR initialized with F140W Kron magnitude: 24.05
# NEIGHBOUR initialized with F140W Kron magnitude: 22.99
# NEIGHBOUR initialized with F140W Kron magnitude: 23.12
# NEIGHBOUR initialized with F140W Kron magnitude: 22.81
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.02
# NEIGHBOUR initialized with F140W Kron magnitude: 24.14
# NEIGHBOUR initialized with F140W Kron magnitude: 22.95
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.91
# NEIGHBOUR initialized with F140W Kron magnitude: 23.46
# NEIGHBOUR initialized with F140W Kron magnitude: 23.08
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.96
# NEIGHBOUR initialized with F140W Kron magnitude: 23.07
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.4
# NEIGHBOUR initialized with F140W Kron magnitude: 24.17
# NEIGHBOUR initialized with F140W Kron magnitude: 23.26
# NEIGHBOUR initialized with F140W Kron magnitude: 23.38
# NEIGHBOUR initialized with F140W Kron magnitude: 23.08
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.39
# NEIGHBOUR initialized with F140W Kron magnitude: 23.74
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.56
# NEIGHBOUR initialized with F140W Kron magnitude: 24.39
# NEIGHBOUR initialized with F140W Kron magnitude: 22.9
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.47
# NEIGHBOUR initialized with F140W Kron magnitude: 24.33
# NEIGHBOUR initialized with F140W Kron magnitude: 23.25
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.58
# NEIGHBOUR initialized with F140W Kron magnitude: 23.47
# NEIGHBOUR initialized with F140W Kron magnitude: 24.02
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.6
# NEIGHBOUR initialized with F140W Kron magnitude: 24.58
# NEIGHBOUR initialized with F140W Kron magnitude: 23.47
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.11
# NEIGHBOUR initialized with F140W Kron magnitude: 23.74
# NEIGHBOUR initialized with F140W Kron magnitude: 23.62
# NEIGHBOUR initialized with F140W Kron magnitude: 23.38
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.85
# NEIGHBOUR initialized with F140W Kron magnitude: 24.86
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.41
# NEIGHBOUR initialized with F140W Kron magnitude: 24.59
# NEIGHBOUR initialized with F140W Kron magnitude: 23.64
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.58
# NEIGHBOUR initialized with F140W Kron magnitude: 23.37
# NEIGHBOUR initialized with F140W Kron magnitude: 24.56
# NEIGHBOUR initialized with F140W Kron magnitude: 23.86
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.97
# NEIGHBOUR initialized with F140W Kron magnitude: 24.4
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.45
# NEIGHBOUR initialized with F140W Kron magnitude: 24.98
# NEIGHBOUR initialized with F140W Kron magnitude: 27.27
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.02
# NEIGHBOUR initialized with F140W Kron magnitude: 23.93
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 22.44
# NEIGHBOUR initialized with F140W Kron magnitude: 24.83
# NEIGHBOUR initialized with F140W Kron magnitude: 23.77
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.67
# NEIGHBOUR initialized with F140W Kron magnitude: 23.9
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.02
# NEIGHBOUR initialized with F140W Kron magnitude: 23.51
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.05
# NEIGHBOUR initialized with F140W Kron magnitude: 24.97
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.75
# NEIGHBOUR initialized with F140W Kron magnitude: 25.27
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.25
# NEIGHBOUR initialized with F140W Kron magnitude: 24.98
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.14
# NEIGHBOUR initialized with F140W Kron magnitude: 25.1
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.89
# NEIGHBOUR initialized with F140W Kron magnitude: 24.74
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.7
# NEIGHBOUR initialized with F140W Kron magnitude: 25.03
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.46
# NEIGHBOUR initialized with F140W Kron magnitude: 25.46
# NEIGHBOUR initialized with F140W Kron magnitude: 24.06
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.69
# NEIGHBOUR initialized with F140W Kron magnitude: 24.19
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.81
# NEIGHBOUR initialized with F140W Kron magnitude: 24.11
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.96
# NEIGHBOUR initialized with F140W Kron magnitude: 24.24
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.21
# NEIGHBOUR initialized with F140W Kron magnitude: 24.02
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.44
# NEIGHBOUR initialized with F140W Kron magnitude: 23.96
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.1
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.17
# NEIGHBOUR initialized with F140W Kron magnitude: 26.34
# Neighbour mag too faint, not being fit
# SAVE_NAME: XLSSC122_galfit_TEST_data_cps__w10HLR_3DHST_F140W_PSF_5min_CONV50_DYNMAG_TEST
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.38
# NEIGHBOUR initialized with F140W Kron magnitude: 25.43
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.74
# NEIGHBOUR initialized with F140W Kron magnitude: 25.3
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.79
# NEIGHBOUR initialized with F140W Kron magnitude: 25.42
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.39
# NEIGHBOUR initialized with F140W Kron magnitude: 24.77
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.19
# NEIGHBOUR initialized with F140W Kron magnitude: 26.01
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.33
# NEIGHBOUR initialized with F140W Kron magnitude: 25.24
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.02
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.87
# NEIGHBOUR initialized with F140W Kron magnitude: 24.24
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.77
# NEIGHBOUR initialized with F140W Kron magnitude: 24.31
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.61
# NEIGHBOUR initialized with F140W Kron magnitude: 27.35
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.41
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.44
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.58
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.55
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.4
# NEIGHBOUR initialized with F140W Kron magnitude: 25.74
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.48
# NEIGHBOUR initialized with F140W Kron magnitude: 26.99
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.74
# NEIGHBOUR initialized with F140W Kron magnitude: 27.37
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.08
# NEIGHBOUR initialized with F140W Kron magnitude: 26.31
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.23
# NEIGHBOUR initialized with F140W Kron magnitude: 27.66
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.1
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.93
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.62
# NEIGHBOUR initialized with F140W Kron magnitude: 26.36
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 23.83
# NEIGHBOUR initialized with F140W Kron magnitude: 26.49
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.15
# NEIGHBOUR initialized with F140W Kron magnitude: 26.7
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.28
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.84
# NEIGHBOUR initialized with F140W Kron magnitude: 24.8
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.33
# NEIGHBOUR initialized with F140W Kron magnitude: 24.86
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.2
# NEIGHBOUR initialized with F140W Kron magnitude: 24.24
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.11
# NEIGHBOUR initialized with F140W Kron magnitude: 24.49
# Neighbour mag too faint, not being fit
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.53
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 24.57
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.4
# NEIGHBOUR initialized with F140W Kron magnitude: 24.59
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.0
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.43
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.61
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.4
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.17
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.8
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.16
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.29
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.36
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.96
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.76
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.64
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.48
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.22
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.84
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.17
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.7
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.79
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.63
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.03
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.66
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.11
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.33
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.29
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.59
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.78
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.77
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.36
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.3
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.93
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.53
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.42
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.83
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.28
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.61
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.27
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.3
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.72
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.27
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.16
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.89
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.56
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.62
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.71
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.27
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.76
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.68
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.7
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.8
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.46
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.14
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.21
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.69
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.03
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.07
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.49
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.13
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.56
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.67
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.29
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.47
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.95
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.98
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.19
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.14
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.5
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.0
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.02
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.5
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.6
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.9
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.08
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.79
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.01
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.34
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.23
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.33
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.83
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.55
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.31
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.79
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.62
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.63
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.98
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.14
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.01
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.58
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.05
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.12
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.25
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.08
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.79
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.83
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.85
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.45
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.84
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.71
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.67
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.9
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.01
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.79
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.51
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.64
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.47
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.54
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.12
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.34
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.51
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.5
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.94
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.58
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.18
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.22
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.45
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.08
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.91
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.32
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.14
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.75
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.62
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.92
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.43
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.51
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.72
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.37
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.21
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.21
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.34
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.21
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.49
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.92
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.96
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.93
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.97
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.23
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.97
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.7
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.45
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 27.25
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 28.28
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 26.92
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.92
# Neighbour mag too faint, not being fit
# NEIGHBOUR initialized with F140W Kron magnitude: 25.95
# Neighbour mag too faint, not being fit
# Using PSF
# **** 1036 ****
# [{'1_RE': '*1.000e-02* +/- *9.464e+01*', '1_N': '4.4476 +/- 15643.6084', '1_MAG': '21.5890 +/- 3370.9041', '1_YC': '401.4019 +/- 20.6630', '1_XC': '400.0550 +/- 25.2843', '1_PA': '37.2033 +/- 39459.1914', '1_AR': '0.7733 +/- 456.6366', 'COMP_1': 'sersic'}, {'2_YC': '[400.0000]', '2_SKY': '-1.733e-04 +/- 6.415e-05', '2_XC': '[400.0000]', '2_DSDX': '[0.000e+00]', '2_DSDY': '[0.000e+00]', 'COMP_2': 'sky'}]
# ['', '1.000e-02', '']
# ['', '9.464e+01', '']
# ['21.5890']
# ['3370.9041']
# ['0.7733']
# ['456.6366']
# ['-1.733e-04']
# ['6.415e-05']
# ID 1036 len(re_val)>1 True
# **** 455 ****
# [{'1_RE': '4.5265 +/- 0.0975', '1_N': '1.4570 +/- 0.0573', '1_MAG': '20.4442 +/- 0.0144', '1_YC': '400.3077 +/- 0.0599', '1_XC': '400.9889 +/- 0.0570', '1_PA': '-23.4776 +/- 5.7121', '1_AR': '0.8752 +/- 0.0186', 'COMP_1': 'sersic'}, {'2_YC': '[400.0000]', '2_SKY': '-2.261e-03 +/- 4.923e-05', '2_XC': '[400.0000]', '2_DSDX': '[0.000e+00]', '2_DSDY': '[0.000e+00]', 'COMP_2': 'sky'}]
# ['4.5265']
# ['0.0975']
# ['20.4442']
# ['0.0144']
# ['0.8752']
# ['0.0186']
# ['-2.261e-03']
# ['4.923e-05']
# ***PROCESS TIMEOUT***
# **** 529 ****
# *** 529 Fit failed at GALFIT level***
# []
# EXCEPTION
# ***PROCESS TIMEOUT***
# **** 661 ****
# *** 661 Fit failed at GALFIT level***
# []
# EXCEPTION
# [(529, 34.434215, -3.758796, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, 1000, 1123), (455, 34.422282, -3.7635129999999997, 4.5265, 0.0975, 0.8752, 0.0186, 1.457, 0.0573, 20.4442, 0.0144, -0.002261, 4.923e-05, 0.6784154, 0), (661, 34.434096000000004, -3.757658, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, -99.0, 1000, 1123), (1036, 34.43245, -3.7499239999999996, 0.01, 94.64, 0.7733, 456.6366, 4.4476, 15643.6084, 21.589, 3370.9041, -0.0001733, 6.415e-05, 0.7768297, 0)]
#      ID         ra       dec       re   re_err       ar    ar_err        n  \
# 0   529  34.434215 -3.758796 -99.0000 -99.0000 -99.0000  -99.0000 -99.0000
# 1   455  34.422282 -3.763513   4.5265   0.0975   0.8752    0.0186   1.4570
# 2   661  34.434096 -3.757658 -99.0000 -99.0000 -99.0000  -99.0000 -99.0000
# 3  1036  34.432450 -3.749924   0.0100  94.6400   0.7733  456.6366   4.4476
#
#         n_err      mag    mag_err        sky    sky_err       chi2nu  \
# 0    -99.0000 -99.0000   -99.0000 -99.000000 -99.000000  1000.000000
# 1      0.0573  20.4442     0.0144  -0.002261   0.000049     0.678415
# 2    -99.0000 -99.0000   -99.0000 -99.000000 -99.000000  1000.000000
# 3  15643.6084  21.5890  3370.9041  -0.000173   0.000064     0.776830
#
#    ErrorValue
# 0        1123
# 1           0
# 2        1123
# 3           0

# %%
new_df
# Out:
#      ID         ra       dec       re   re_err       ar    ar_err        n  \
# 0   529  34.434215 -3.758796 -99.0000 -99.0000 -99.0000  -99.0000 -99.0000
# 1   455  34.422282 -3.763513   4.5265   0.0975   0.8752    0.0186   1.4570
# 2   661  34.434096 -3.757658 -99.0000 -99.0000 -99.0000  -99.0000 -99.0000
# 3  1036  34.432450 -3.749924   0.0100  94.6400   0.7733  456.6366   4.4476
#
#         n_err      mag    mag_err        sky    sky_err       chi2nu  \
# 0    -99.0000 -99.0000   -99.0000 -99.000000 -99.000000  1000.000000
# 1      0.0573  20.4442     0.0144  -0.002261   0.000049     0.678415
# 2    -99.0000 -99.0000   -99.0000 -99.000000 -99.000000  1000.000000
# 3  15643.6084  21.5890  3370.9041  -0.000173   0.000064     0.776830
#
#    ErrorValue
# 0        1123
# 1           0
# 2        1123
# 3           0

# %%
for i in new_df['ID'][0:10]:
    print i 
    plot_by_ID(i,save_name=save_name)
# Out:
# 529
# ID: 529
# ttdf[ID] 0     529
# 1     455
# 2     661
# 3    1036
# Name: ID, dtype: int64
# No model fit found. Plotting raw image from /cutout.fits
# No cutout.fits file found...
# 455
# ID: 455
# ttdf[ID] 0     529
# 1     455
# 2     661
# 3    1036
# Name: ID, dtype: int64
# 661
# ID: 661
# ttdf[ID] 0     529
# 1     455
# 2     661
# 3    1036
# Name: ID, dtype: int64
# No model fit found. Plotting raw image from /cutout.fits
# No cutout.fits file found...
# 1036
# ID: 1036
# ttdf[ID] 0     529
# 1     455
# 2     661
# 3    1036
# Name: ID, dtype: int64
